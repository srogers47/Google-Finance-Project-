# %% [markdown]
# # The U.S. Financial Crisis (2006 - 2016)

# %% [markdown]
# ### In this project, we will be looking at bank stock prices between 2006 and 2016. We are interested in how the stocks of the following companies fluxuated during the financial crisis.
#        * Bank of America
#        * CitiGroup
#        * Goldman Sachs
#        * JPMorgan Chase
#        * Morgan Stanley
#        * Wells Fargo
# Stock datapoints will be sourced from AlphaVantage API.

# %%
#Imports 
import pandas_datareader as web
import os
from dotenv import load_dotenv 
import pandas as pd 
import numpy as np
import datetime
import matplotlib.pyplot as plt 
# %matplotlib inline 
#Load alphavatage api key from secret .env file. 
# %load_ext dotenv
# %dotenv

# %% [markdown]
# #### Use the source_tickers.py program included in repo to extract and preprocess data from  the AlphaVantage API.

# %%
#Read extracted stock data into notebook. 
bank_stocks = pd.read_csv("./bank_stocks.csv")
bank_stocks.head()
# Out:
#      BAC  BAC.1  BAC.2  BAC.3     BAC.4      C    C.1    C.2    C.3       C.4  \
# 0   open   high    low  close    volume   open   high    low  close    volume
# 1  46.92  47.18  46.15  47.08  16296700   49.0  49.38  48.11  49.29  15376000
# 2   47.0  47.24  46.45  46.58  17757900  48.86   49.1  48.35  48.38  18709000
# 3  46.58  46.83  46.32  46.64  14970700  48.44  48.78   48.4  48.62  11431000
# 4   46.8  46.91  46.35  46.57  12599800  48.88   48.9   48.2  48.62  13702000
#
#    ...     MS   MS.1   MS.2   MS.3     MS.4    WFC  WFC.1  WFC.2  WFC.3  \
# 0  ...   open   high    low  close   volume   open   high    low  close
# 1  ...  57.17  58.49  56.74  58.31  5377000   63.2  63.95  62.39   63.8
# 2  ...   58.7  59.28  58.35  58.35  7977800   63.6  63.64  62.73  63.06
# 3  ...  58.55  58.59  58.02  58.51  5778000   63.0  63.11  62.62  62.99
# 4  ...  58.77  58.85  58.05  58.57  6889800  63.16  63.55  62.77  63.36
#
#      WFC.4
# 0   volume
# 1  5508200
# 2  5435000
# 3  5079000
# ...

# %% [markdown]
# ### Exploratory Data Analysis.

# %%
#What's the max close price for each company stock during the Recession?
bank_stocks['Date']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/projects/udemy_projects/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-bbd7acb32210> in <module>
# ...
